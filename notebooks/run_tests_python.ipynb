# %%
import sys
import os

# add the Python package root
sys.path.append(os.path.abspath('../python'))

# %%
# %run ../tests/python/tests.py
# Out:
# Running NSRA unit tests...
#
# Perfect ordering
#   NSRA: 1.000
#   MAE : 4.600
#
# Reverse ordering
#   NSRA: 0.000
#   MAE : 2.400
#
# All null
#   NSRA: nan
#   MAE : 0.753
#
# Predicted ties
#   NSRA: 0.500
#   MAE : 0.667
#
# False positives (ranked below true U)
#   NSRA: 1.000
#   MAE : 1.206
#
# False positives (interleaved)
#   NSRA: 0.512
#   MAE : 4.921
#
# False positives (ranked safely)
#   NSRA: 1.000
#   MAE : 1.206
#
# False negatives (collapsed to NULL)
#   NSRA: 0.500
#   MAE : 0.333
#
# Sparse (single gene correct)
#   NSRA: 1.000
#   MAE : 0.890
#
# Sparse (single gene wrong direction)
#   NSRA: 0.000
#   MAE : 0.945
#
# [PYTHON] Elapsed times: 9.827 (full-pairwise) vs 0.300 (rank-reduced) vs 0.052 (compiled)
#
#
# All tests passed successfully!
