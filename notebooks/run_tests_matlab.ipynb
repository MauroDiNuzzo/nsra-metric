% %%
addpath('../matlab');

% %%
run('../tests/matlab/tests.m')
% Out:
% Running NSRA unit tests...
%
% Perfect ordering
%   NSRA: 1.000
%   MAE : 4.600
%
% Reverse ordering
%   NSRA: 0.000
%   MAE : 2.400
%
% All null
%   NSRA: NaN
%   MAE : 1.424
%
% Predicted ties
%   NSRA: 0.500
%   MAE : 0.667
%
% False positives (below true signal)
%   NSRA: 1.000
%   MAE : 1.206
%
% False positives (interleaved)
%   NSRA: 0.512
%   MAE : 4.921
%
% False positives (ranked safely)
%   NSRA: 1.000
%   MAE : 1.206
%
% False negatives (collapsed to NULL)
%   NSRA: 0.500
%   MAE : 0.333
%
% Sparse perturbation (correct)
%   NSRA: 1.000
%   MAE : 0.883
%
% Sparse perturbation (wrong direction)
%   NSRA: 0.000
%   MAE : 1.000
%
% [MATLAB] Elapsed times: 13.794 (full-pairwise) vs 0.007 (rank-reduced) vs 1.966 (compiled)
%
%
% All tests passed successfully!
